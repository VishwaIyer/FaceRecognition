# %%
# !wget --no-check-certificate \https://raw.githubusercontent.com/computationalcore/introduction-to-opencv/master/assets/haarcascade_frontalface_default.xml \-O haarcascade_frontalface_default.xml
# Out:
# --2020-11-15 14:02:43--  https://raw.githubusercontent.com/computationalcore/introduction-to-opencv/master/assets/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘haarcascade_frontalface_default.xml’
#
# haarcascade_frontal 100%[===================>] 908.33K  --.-KB/s    in 0.04s
#
# 2020-11-15 14:02:44 (19.8 MB/s) - ‘haarcascade_frontalface_default.xml’ saved [930127/930127]

# %%
# !pip install opencv-python
# !pip install numpy
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python) (1.18.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (1.18.5)

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# multiple cascades: https://github.com/Itseez/opencv/tree/master/data/haarcascades
faceCascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

img=cv2.imread('Vishwa.jpeg')
    
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,
        
        scaleFactor=1.2,
        minNeighbors=5,     
        minSize=(10, 10)
    )
font=cv2.FONT_HERSHEY_SIMPLEX

fontScale=1
color=(0,0,255)
thickness=2
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    cv2.putText(img,'Vishwa',(x,y), font, fontScale, 
                color,thickness)
        

cv2_imshow(img)

k = cv2.waitKey(30) & 0xff
img.release()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=864x1152 at 0x7F7BF37F8C50>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-04d6bffc76b3> in <module>()
#      31
#      32 k = cv2.waitKey(30) & 0xff
# ---> 33 img.release()
#      34 cv2.destroyAllWindows()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'release'
